# %% [markdown]
# # Notebook Dedicated to study the dE/dx on RAT

# %%
import uproot
import numpy as np

# %%
fdir = '/home/joankl/data/rat_test/rat_v8/protondEdx.root'

file = uproot.open(fdir)
file.keys()
# Out:
# ['T;1', 'runT;1', 'log;1', 'macro;1', 'db;1', 'meta;1']

# %%
data =
